# %%
import pandas as pd

# %%
data = pd.read_csv('result.txt-00000-of-00001')
data.head(10)
# Out:
#    {'reviews_per_month': u'0.21'    'neighbourhood_group': u'Brooklyn'  \
# 0  {'reviews_per_month': u'0.38'   'neighbourhood_group': u'Manhattan'
# 1      {'reviews_per_month': u''   'neighbourhood_group': u'Manhattan'
# 2  {'reviews_per_month': u'4.64'    'neighbourhood_group': u'Brooklyn'
# 3  {'reviews_per_month': u'0.10'   'neighbourhood_group': u'Manhattan'
# 4  {'reviews_per_month': u'0.59'   'neighbourhood_group': u'Manhattan'
# 5  {'reviews_per_month': u'0.40'    'neighbourhood_group': u'Brooklyn'
# 6  {'reviews_per_month': u'3.47'   'neighbourhood_group': u'Manhattan'
# 7  {'reviews_per_month': u'0.99'   'neighbourhood_group': u'Manhattan'
# 8  {'reviews_per_month': u'1.33'   'neighbourhood_group': u'Manhattan'
# 9  {'reviews_per_month': u'0.43'   'neighbourhood_group': u'Manhattan'
#
#        'name': u'Clean & quiet apt home by the park'  \
# 0                   'name': u'Skylit Midtown Castle'
# 1     'name': u'THE VILLAGE OF HARLEM....NEW YORK !'
# ...

# %%
len(data)
# Out:
# 49079

# %%
data.shape
# Out:
# (49079, 16)

# %%
data.columns[5]
# Out:
# " 'longitude': u'-73.97237'"
